# %%
pat = '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'
# !git clone https://{pat}@github.com/Ayushi26Aggarwal/BetalyticsNBA.git
# Out:
# Cloning into 'BetalyticsNBA'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 44 (delta 25), reused 9 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (44/44), 3.57 MiB | 6.16 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %%
cd /content/BetalyticsNBA
# Out:
# /content/BetalyticsNBA

# %%
import requests
import pandas as pd
import json
import re

# %%
# Define the URL for the API request
url = "https://api.the-odds-api.com/v4/sports/basketball_nba/events?apiKey=96e45b9af0dcb5961e81d736ca4d1b59&markets=player_stealss&regions=us"

# Send a GET request to the URL
response = requests.get(url)

# Get the content of the response as text
content = response.text

# Remove the non-JSON parts
content = re.sub(r"^angular.callbacks._\d+\(", "", content)
content = re.sub(r"\);$", "", content)

# Load the JSON data into a DataFrame
df = pd.read_json(content)
# Out:
# <ipython-input-4-6f21daaca0ee>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(content)

# %%
points = pd.DataFrame()

# %%
for i in range(len(df)):
  print(i)
  url = "https://api.the-odds-api.com/v4/sports/basketball_nba/events/"+df['id'][i]+"/odds?apiKey=96e45b9af0dcb5961e81d736ca4d1b59&markets=player_steals&regions=us"
  # Send a GET request to the URL
  response = requests.get(url)

  # Get the content of the response as text
  content = response.text

  # Remove the non-JSON parts
  content = re.sub(r"^angular.callbacks._\d+\(", "", content)
  content = re.sub(r"\);$", "", content)

  # Load the JSON data into a DataFrame
  df1 = pd.read_json(content)
  # Extract the bookmakers into a DataFrame
  bookmakers_df = pd.json_normalize(df1['bookmakers'])
  fanduel = True
  j = 0
  while fanduel & len(bookmakers_df != 0):
    if bookmakers_df['key'][j] == 'fanduel':
      market = pd.DataFrame(bookmakers_df['markets'][j])
      market = pd.DataFrame(market['outcomes'][0])
      fanduel = False
    j += 1
  print(int(len(market)/2))
  for k in range(int(len(market)/2)):
    print(k)
    row = [[df['id'][i], df['commence_time'][i], df['home_team'][i], df['away_team'][i], market['description'][k*2], market['point'][k*2], market['price'][k*2], market['price'][((k+1)*2)-1]]]
    points = pd.concat([points,pd.DataFrame(row)], ignore_index=True)
# Out:
# 0
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 2
# 0
# 1
# 1
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 2
# 0
# 1
# 2
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 3
# 0
# 1
# 2
# 3
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 3
# 0
# 1
# 2
# 4
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 3
# 0
# 1
# 2
# 5
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 3
# 0
# 1
# 2
# 6
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 3
# 0
# 1
# 2
# 7
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 3
# 0
# 1
# 2
# 8
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)
# 3
# 0
# 1
# 2
# 9
# 3
# 0
# 1
# 2
# <ipython-input-6-bed824f7b73f>:15: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_json(content)

# %%
points
# Out:
#                                    0                         1  \
# 0   8371571bb6059f03debc55b594422565 2024-11-27 00:00:00+00:00
# 1   8371571bb6059f03debc55b594422565 2024-11-27 00:00:00+00:00
# 2   979282582fedc5d942f4f0f2f22763ee 2024-11-27 00:30:00+00:00
# 3   979282582fedc5d942f4f0f2f22763ee 2024-11-27 00:30:00+00:00
# 4   312350cf1c97873d6cb81224bac3873e 2024-11-27 01:00:00+00:00
# 5   312350cf1c97873d6cb81224bac3873e 2024-11-27 01:00:00+00:00
# 13         New York Knicks       San Antonio Spurs      Collin Sexton  1.5
# 14         New York Knicks       San Antonio Spurs         Chris Paul  1.5
# 15         New York Knicks       San Antonio Spurs  Victor Wembanyama  1.5
# 16        Dallas Mavericks  Minnesota Timberwolves      Collin Sexton  1.5
# 17        Dallas Mavericks  Minnesota Timberwolves         Chris Paul  1.5
# 18        Dallas Mavericks  Minnesota Timberwolves  Victor Wembanyama  1.5
# 19          Boston Celtics      Philadelphia 76ers      Collin Sexton  1.5
# 20          Boston Celtics      Philadelphia 76ers         Chris Paul  1.5
# 21          Boston Celtics      Philadelphia 76ers  Victor Wembanyama  1.5
# 22   Golden State Warriors      Los Angeles Lakers      Collin Sexton  1.5
# 23   Golden State Warriors      Los Angeles Lakers         Chris Paul  1.5
# 24   Golden State Warriors      Los Angeles Lakers  Victor Wembanyama  1.5
# 25            Phoenix Suns          Denver Nuggets      Collin Sexton  1.5
# 26            Phoenix Suns          Denver Nuggets         Chris Paul  1.5
# 27            Phoenix Suns          Denver Nuggets  Victor Wembanyama  1.5
#
#        6     7
# 0   2.50  1.52
# 1   2.40  1.56
# 2   2.50  1.52
# 3   2.40  1.56
# 4   2.54  1.50
# 5   1.96  1.82
# 6   2.52  1.51
# 7   3.00  1.38
# 8   1.96  1.82
# 9   2.58  1.49
# 10  3.00  1.38
# 11  1.96  1.82
# 12  2.58  1.49
# 13  3.00  1.38
# 14  1.96  1.82
# 15  2.58  1.49
# 16  3.00  1.38
# 17  1.96  1.82
# 18  2.58  1.49
# 19  3.00  1.38
# 20  1.96  1.82
# 21  2.58  1.49
# 22  3.00  1.38
# 23  1.96  1.82
# 24  2.58  1.49
# 25  3.00  1.38
# 26  1.96  1.82
# 27  2.58  1.49

# %%
points.columns=['id', 'commence_time', 'home_team', 'away_team', 'Player Name', 'point', 'over price', 'under price']

# %%
old_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/MoneylineOddsAPI.csv')
write_data = pd.concat([old_data.iloc[:,1:],new_df], ignore_index=True)
write_data['commence_time'] = pd.to_datetime(write_data['commence_time'])
write_data = write_data.drop_duplicates(['id','home_team', 'away_team'])
write_data.to_csv('/content/drive/MyDrive/Colab Notebooks/MoneylineOddsAPI.csv')

# %%
points.to_csv('/content/BetalyticsNBA/PlayerSteals.csv')

# %%
#new_df
# !git init






## Step 2: Set your account identity in this repository.
##########
# !git config user.email "ayushi.aggarwal@brainiuminfotech.com"
# !git config user.name "Ayushi26Aggarwal"






## Step 3: Make the first commit
##########
# git isn't aware of the file READ.md , stage it
# !git add .

# commit the staged changes with a message
# !git commit -m "PlayerSteals.csv"

# !git push origin main
# Out:
# Reinitialized existing Git repository in /content/BetalyticsNBA/.git/
# [main c11d830] PlayerSteals.csv
#  1 file changed, 29 insertions(+)
#  create mode 100644 PlayerSteals.csv
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.08 KiB | 1.08 MiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Ayushi26Aggarwal/BetalyticsNBA.git
#    dc0e961..c11d830  main -> main
